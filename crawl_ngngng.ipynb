# %% [markdown]
# <a href="https://colab.research.google.com/github/research-clone/uvr_remove_music/blob/main/crawl_ngngng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/
# !rm -rf speech-synthesis-ngngngan
# !git clone https://github.com/research-clone/speech-synthesis-ngngngan.git
# Out:
# /content
# Cloning into 'speech-synthesis-ngngngan'...
# remote: Enumerating objects: 264, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 264 (delta 90), reused 85 (delta 55), pack-reused 137
# Receiving objects: 100% (264/264), 41.30 MiB | 28.91 MiB/s, done.
# Resolving deltas: 100% (154/154), done.

# %%
# %cd /content/speech-synthesis-ngngngan/
# !pwd
# !git pull https://github.com/research-clone/speech-synthesis-ngngngan.git
# Out:
# /content/speech-synthesis-ngngngan
# /content/speech-synthesis-ngngngan
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0
# Unpacking objects: 100% (5/5), 393 bytes | 393.00 KiB/s, done.
# From https://github.com/research-clone/speech-synthesis-ngngngan
#  * branch            HEAD       -> FETCH_HEAD
# Updating 0e9be8f..47e7cab
# Fast-forward
#  scripts/uvr/separate.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install yt-dlp
# 2024.7.25 version
# !pip show yt-dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 86.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 104.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 21.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 86.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install librosa==0.9.1
# !pip uninstall cmake -y
# !pip install samplerate
# !pip install numpy==1.23.5
# !pip install pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 87.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.2.post1
#     Uninstalling librosa-0.10.2.post1:
#       Successfully uninstalled librosa-0.10.2.post1
# ...
# Found existing installation: cmake 3.30.1
# Uninstalling cmake-3.30.1:
#   Successfully uninstalled cmake-3.30.1
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for samplerate: filename=samplerate-0.2.1-cp310-cp310-linux_x86_64.whl size=1453528 sha256=2aeecbc9833a2ea43c3452adb04f088e120e608254d8b662b2663d8ccddf1927
#   Stored in directory: /root/.cache/pip/wheels/15/e6/9c/8edf8bcba77efeb0f90f3d667344eb84425e19f2169bb3a0b3
# Successfully built samplerate
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 95.3 MB/s eta 0:00:00
# ...

# %%
# %cd /content/speech-synthesis-ngngngan/
# !python scripts/00-get-info.py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 59.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 81.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 89.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# %cd /content/speech-synthesis-ngngngan/
# !python scripts/01-download-audio.py
# Out:
# /content/speech-synthesis-ngngngan
# download 19 files
# [youtube] Extracting URL: hoNGMejbF20
# [youtube] hoNGMejbF20: Downloading webpage
# [youtube] hoNGMejbF20: Downloading ios player API JSON
# [youtube] hoNGMejbF20: Downloading m3u8 information
# [info] hoNGMejbF20: Downloading 1 format(s): 251
# [download] Destination: data/01-raw/hoNGMejbF20.webm
# [download] 100% of   18.26MiB in 00:00:00 at 18.99MiB/s
# [ExtractAudio] Destination: data/01-raw/hoNGMejbF20.wav
# Deleting original file data/01-raw/hoNGMejbF20.webm (pass -k to keep)
# [youtube] Extracting URL: IeDjubTdvXY
# [youtube] IeDjubTdvXY: Downloading webpage
# [youtube] IeDjubTdvXY: Downloading ios player API JSON
# [youtube] IeDjubTdvXY: Downloading m3u8 information
# [info] IeDjubTdvXY: Downloading 1 format(s): 251
# [download] Destination: data/01-raw/IeDjubTdvXY.webm
# [download] 100% of   22.36MiB in 00:00:00 at 26.31MiB/s
# [ExtractAudio] Destination: data/01-raw/IeDjubTdvXY.wav
# ...

# %%
# !pwd
import os
os.makedirs("/content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw", exist_ok=True)
# !mv /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw/01-raw/*.wav /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw/
# !cp -r data/01-raw /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw/
# !cp data/data.json /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/
# !cp data/draft.json /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/
# Out:
# /content/speech-synthesis-ngngngan

# %%
# %cd /content/speech-synthesis-ngngngan/
# !python scripts/remove_silence.py --input_dir "/content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw" \
--output_dir "/content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/2.5-vad-autosplit"
# Out:
# /content/speech-synthesis-ngngngan
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:293: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/snakers4/silero-vad/zipball/master" to /root/.cache/torch/hub/master.zip
# /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw/hoNGMejbF20.wav
#  98% 16551476.561825123/16947224 [00:19<00:00, 828139.29it/s]
# speech_timestamps length: 430
# ...

# %%
# %cd /content/speech-synthesis-ngngngan/
# !python3 scripts/audio_splitter.py --input_dir "/content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw" \
--output_dir "/content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/1.5-raw-split" \
--split_threshold 1200 \
--accept_threshold 1500
# Out:
# /content/speech-synthesis-ngngngan
# NOT long audio: /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw/hoNGMejbF20.wav
# NOT long audio: /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw/IeDjubTdvXY.wav
# NOT long audio: /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw/m4N42aD6Twg.wav
# NOT long audio: /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw/9OvlclzngLY.wav
# NOT long audio: /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw/ZJiM8YGHDPQ.wav
# NOT long audio: /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw/ELbEiuSHSoE.wav
# NOT long audio: /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw/-7aAnBs8WQc.wav
# Long audio: /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/01-raw/CDlujtWFuJE.wav
# len chunks: 51
# CDlujtWFuJE
# CDlujtWFuJE
# CDlujtWFuJE
# CDlujtWFuJE
# CDlujtWFuJE
# CDlujtWFuJE
# CDlujtWFuJE
# CDlujtWFuJE
# CDlujtWFuJE
# CDlujtWFuJE
# ...

# %%
# %cd /content/speech-synthesis-ngngngan/
# !python scripts/02-remove-silence.py --input_dir "/content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/1.5-raw-split" \
--output_dir "/content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/02.5-vad-split"
# Out:
# /content/speech-synthesis-ngngngan
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:293: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/snakers4/silero-vad/zipball/master" to /root/.cache/torch/hub/master.zip
# /content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/1.5-raw-split/hoNGMejbF20.wav
#  98% 16551476.561825123/16947224 [00:19<00:00, 843813.84it/s]
# ...

# %%
# %cd /content/speech-synthesis-ngngngan/
# %cd scripts/uvr
# !bash download.sh
# !python3 separate.py --audio_path "/content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/2.5-vad-autosplit" \
--save_path "/content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/4.5-vad-autosplit-rmmusic" \
--only_save_vocal
# Out:
# /content/speech-synthesis-ngngngan
# /content/speech-synthesis-ngngngan/scripts/uvr
# Download the model weights
# The model weights have been downloaded
# processing 0 - hoNGMejbF20_part0.wav
# 100% 285/285 [00:18<00:00, 15.55it/s]
# hoNGMejbF20_part0.wav vocals done
# processing 1 - IeDjubTdvXY_part0.wav
# 100% 323/323 [00:19<00:00, 16.44it/s]
# IeDjubTdvXY_part0.wav vocals done
# processing 2 - IeDjubTdvXY_part1.wav
# 100% 27/27 [00:01<00:00, 15.81it/s]
# IeDjubTdvXY_part1.wav vocals done
# processing 3 - m4N42aD6Twg_part0.wav
# 100% 243/243 [00:14<00:00, 16.40it/s]
# m4N42aD6Twg_part0.wav vocals done
# processing 4 - 9OvlclzngLY_part0.wav
# 100% 314/314 [00:19<00:00, 16.43it/s]
# 9OvlclzngLY_part0.wav vocals done
# processing 5 - ZJiM8YGHDPQ_part0.wav
# 100% 235/235 [00:14<00:00, 16.40it/s]
# ZJiM8YGHDPQ_part0.wav vocals done
# processing 6 - ELbEiuSHSoE_part0.wav
# 100% 251/251 [00:15<00:00, 16.36it/s]
# ELbEiuSHSoE_part0.wav vocals done
# processing 7 - -7aAnBs8WQc_part0.wav
# ...

# %%
# !pip install openai-whisper
import torch
import gc
gc.collect()
torch.cuda.empty_cache()

import whisper

model = whisper.load_model("medium", device='cuda')
infile = "/content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/4.5-vad-autosplit-rmmusic/vocal_2_HP-UVR_ZbKrts2AtYQ_part2.wav"
res = model.transcribe(infile, language="vi")
print(res)
# Out:
# {'text': ' nhất là cầm hương từng nức tiếng về nhân sắc. Có tờ báo mô tả cô là một hoa khôi đẹp mê hồn, lúc ấy, Lạm Phương đã bước vào tuổi trung niên. Nên anh viết ngay bài Nở đời yêu em, rồi nối tiếp luôn một loạt tình ca chan hòa ảnh phúc, như bài Tăng ô cho em, Thiên đường ái ân, mùa thu yêu đường, chỉ có em. Vân vân, lời ca của anh bây giờ vui tươi và thực tế lắm, bởi anh vừa phục sinh, sau những ngày dài mất hết niềm tin trong cuộc sống. Bây giờ anh viết đường vào Paris có lắm nụ hồng, anh nhắc đến những nụ hồng, bởi đó là tên người tình mới, tức là Hường Ách. Nói chung, giai đoạn này nhạc Lạm Phương, chuyển sang một hướng mới, tìm lại được niềm tin yêu trong cuộc đời, bỏ lại sau lưng tất cả chuỗi ngày vất vỡ vừa qua. Sau đây là bài hát Điền Ninh, cho thời hồi sinh của Lạm Phương, đó là bài Tăng ô cho em. Nhà mình tràn ánh hề, dòng nhạc tình đã tắt lâu, tuôn trao ngọt gào su. Trong mặt em buồn vếm, mới có khi nào, lần gặp đấy cho mai sau. Em là riêng thế, giờ mình, có đẹp vì ti
# ...

# %%
# !pip install datasets
# !pip install pyarrow==14.0.1
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
from datasets import load_dataset
import soundfile as sf
import torch

# load model and tokenizer
processor = Wav2Vec2Processor.from_pretrained("nguyenvulebinh/wav2vec2-base-vietnamese-250h")
model = Wav2Vec2ForCTC.from_pretrained("nguyenvulebinh/wav2vec2-base-vietnamese-250h")

infile = "/content/drive/MyDrive/AIAgent/crawl_dataset/nguyenngocngan/4.5-vad-autosplit-rmmusic/vocal_2_HP-UVR_ZbKrts2AtYQ_part2.wav"

# define function to read in sound file
def map_to_array(batch):
    speech, _ = sf.read(batch["file"])
    batch["speech"] = speech
    return batch

# load dummy dataset and read soundfiles
ds = map_to_array({
    "file": infile
})

# tokenize
input_values = processor(ds["speech"], return_tensors="pt", padding="longest").input_values  # Batch size 1

# retrieve logits
logits = model(input_values).logits

# take argmax and decode
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.batch_decode(predicted_ids)
print(transcription)
# Out:
# ...
# Some weights of the model checkpoint at nguyenvulebinh/wav2vec2-base-vietnamese-250h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...
